# %% [markdown]
# # Laboratory Work: Chickenpox Propagation Prediction/Forecasting
#
# - The objective of this Laboratry Work is to put in application time series data forecasting using a **Deep Neural Network**. For that it is nececssary to learn the model behind the time series data giving the relation between output, input, and their past and future values as given in the relation below:
# $$y(k+p)=F(y(k),y(k-1),\ldots,y(k-d_y), u(k),u(k-1),u(k-2),\ldots,u(k-d_u))$$
# where:
#     - $y(k)$: is the output predicted signal
#     - $u(k)$: is the input signal
#     - $p$: is the prediction horizont
#     - $d_y$: is the output memory/delay order or output prediction order
#     - $d_u$: is the input memory/delay order  or input prediction order
# - In our application  $p>0$, $d_u=0$ and $d_y>0$
# - We will resolve this prediction problem by transforming the related recurrent Neural Network to a feedforword Neural Network and using the learning algorithms and tools provided by Keras toolbox. So if we consider that we have a learning base given by $u(k), y(k), k=1,2,\ldots, n $ we have to create one input signal from input learning base $u(k)$ and $d_y+1$ input signal coming from $y(k)$ and its $d_y$  delayed signals. We can begin the prediction learning with $p=1$, $d_y=7$ and $d_u=0$ as given in the construction of learning base in section *Data Base*.
# - **Work to be done**:
#     - For different perdiction horizon $p\in{1,2,3}$ and memory/predictor order $d_y\in{7,8,9,10}$ propose a Neural Network  architecture, operate the learning phase, give the results of testing phase and make some conclusions wrt accuracy.
#     - **Optional**: Propose an implementation of Back Propogation algorithm to operate the learning phase.
#     - **Optional**: Propose other Neuronal Network architecture like SimpleRNN, GRU or LSTM to implement and operate the learning and compare your results with the feedforward architecture given above.
#     - Genral conclusion
# - **A report** on the Laboratory Work has to be written in **Jupyter** or in any other editor.
# - **The report** as well as **Jupyter report and code** has to be uploaded to Blackboard  **before 24 of April 2022**  specifying the name of persons involved (**which has to be at maximun two**). The name of the persons involved has to be given in the report also.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics
from keras import activations
# Out:
# 2023-04-05 09:33:04.420788: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-05 09:33:04.490169: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-05 09:33:04.490884: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 09:33:05.287542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Base
# - The example trains an **Deep neural Network** to forecast the number of chickenpox cases, taken from the data set **chickenpox_dataset**, given the number of cases in previous months
# - Load the example data from **data_chickenpox.txt** text file which contains a single time series, with time steps corresponding to months and values corresponding to the number of cases
# - Construct the input **Deep Neural Network** input w.r.t delay order or output prediction order
# - Split the data in **Training Set**, **Validation Set** and **Test Set**
# - $nn_0$ gives the output prediction order or number of neurons in the input layer
# - $nn_1$ gives the number of neurons in the hidden layer
# - $nn_2$ gives the number of neurons in the output layer

# %%
S= np.loadtxt('data_chickenpox.txt')
n=len(S)
plt.plot(S)
plt.title('Chickenpox data')
plt.xlabel('in months')
plt.ylabel('number of cases')
plt.show()

p=1                                      
dy=7                                     
nn_0=dy+1                                
nn_1=10                                  
nn_2=1                                      
y=S

V=y[dy:len(y)-p,]
for i in range(1, dy+1):
    V=np.c_[V,y[dy-i:len(y)-p-i,]]   

T=np.mat(y[dy+p:len(y),]).T
print(V.shape)
print(T.shape)
input_NN=V[:400,:]
target_NN=T[:400,]
input_Test=V[400:,:]
target_Test=T[400:,]
# Out:
# (490, 8)
# (490, 1)

# %% [markdown]
# # Standardize Data
# For a better fit and to prevent the training from diverging, standardize the training data to have zero mean and unit variance. Standardize the test data using the same parameters as the training data.

# %%
input_mean = np.mean(input_NN)
target_mean = np.mean(target_NN)
input_std = np.std(input_NN)
target_std = np.std(target_NN)

input_NN = (input_NN - input_mean) / input_std
target_NN = (target_NN - input_mean) / target_std
input_Test = (input_Test - input_mean) / input_std
target_Test = (target_Test - target_mean) / target_std

# %% [markdown]
# # Deep Neural Network Architecture
# - Define the type of DNN: In our case we have chosen the **Sequential** DNN
# - Define the type of activation function for each layer (**linear,relu,linear** in our case)
# - Define the learning/optimization method used (**RMSprop** in our case)
# - Define the criteria to minimize and the related metric (**MSE** and **'mae'** in our case)
# - Define the **batch size** and the number of **epochs** (**batch_size=4, epochs=50** in our case)
# - $nn_0$ gives the prediction order or number of neurons in the input layer
# - $nn_1$ gives the number of neurons in the hidden layer
# - $nn_2$ gives the number of neurons in the output layer

# %%
model = models.Sequential()

model.add(layers.Dense(nn_0, activation=activations.linear))
model.add(layers.Dense(nn_1, activation=activations.relu))
model.add(layers.Dense(nn_2, activation=activations.linear))

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001), loss=losses.mean_squared_error, metrics=[metrics.mean_absolute_error])

history = model.fit(input_NN, target_NN, epochs=50, batch_size=4, validation_data=(input_Test, target_Test))
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 3ms/step - loss: 1.0461 - mean_absolute_error: 0.8201 - val_loss: 0.8292 - val_mean_absolute_error: 0.8264
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3589 - mean_absolute_error: 0.4854 - val_loss: 0.6234 - val_mean_absolute_error: 0.7246
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2268 - mean_absolute_error: 0.3827 - val_loss: 0.4105 - val_mean_absolute_error: 0.5811
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1870 - mean_absolute_error: 0.3457 - val_loss: 0.2675 - val_mean_absolute_error: 0.4604
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1675 - mean_absolute_error: 0.3205 - val_loss: 0.2088 - val_mean_absolute_error: 0.4028
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1544 - mean_absolute_error: 0.3045 - val_loss: 0.1474 - val_mean_absolute_error: 0.3322
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1465 - mean_absolute_error: 0.2884 - val_loss: 0.1446 - val_mean_absolute_error: 0.3338
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1398 - mean_absolute_error: 0.2808 - val_loss: 0.1226 - val_mean_absolute_error: 0.2999
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1341 - mean_absolute_error: 0.2723 - val_loss: 0.1232 - val_mean_absolute_error: 0.3072
# Epoch 10/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1312 - mean_absolute_error: 0.2708 - val_loss: 0.1051 - val_mean_absolute_error: 0.2731
# Epoch 11/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1271 - mean_absolute_error: 0.2622 - val_loss: 0.1001 - val_mean_absolute_error: 0.2700
# Epoch 12/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1246 - mean_absolute_error: 0.2580 - val_loss: 0.1256 - val_mean_absolute_error: 0.3048
# Epoch 13/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1208 - mean_absolute_error: 0.2540 - val_loss: 0.0976 - val_mean_absolute_error: 0.2636
# Epoch 14/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1200 - mean_absolute_error: 0.2523 - val_loss: 0.0907 - val_mean_absolute_error: 0.2489
# Epoch 15/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1174 - mean_absolute_error: 0.2467 - val_loss: 0.0958 - val_mean_absolute_error: 0.2585
# Epoch 16/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1160 - mean_absolute_error: 0.2464 - val_loss: 0.0899 - val_mean_absolute_error: 0.2496
# Epoch 17/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1141 - mean_absolute_error: 0.2446 - val_loss: 0.1270 - val_mean_absolute_error: 0.3016
# Epoch 18/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1130 - mean_absolute_error: 0.2440 - val_loss: 0.1080 - val_mean_absolute_error: 0.2810
# Epoch 19/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1131 - mean_absolute_error: 0.2393 - val_loss: 0.0905 - val_mean_absolute_error: 0.2548
# Epoch 20/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1114 - mean_absolute_error: 0.2411 - val_loss: 0.0885 - val_mean_absolute_error: 0.2450
# Epoch 21/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1107 - mean_absolute_error: 0.2370 - val_loss: 0.0965 - val_mean_absolute_error: 0.2626
# Epoch 22/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1082 - mean_absolute_error: 0.2324 - val_loss: 0.0943 - val_mean_absolute_error: 0.2609
# Epoch 23/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1073 - mean_absolute_error: 0.2366 - val_loss: 0.0909 - val_mean_absolute_error: 0.2530
# Epoch 24/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1075 - mean_absolute_error: 0.2359 - val_loss: 0.0964 - val_mean_absolute_error: 0.2589
# Epoch 25/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1068 - mean_absolute_error: 0.2358 - val_loss: 0.0818 - val_mean_absolute_error: 0.2367
# Epoch 26/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1061 - mean_absolute_error: 0.2307 - val_loss: 0.0775 - val_mean_absolute_error: 0.2277
# Epoch 27/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1062 - mean_absolute_error: 0.2314 - val_loss: 0.1148 - val_mean_absolute_error: 0.2873
# Epoch 28/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1029 - mean_absolute_error: 0.2300 - val_loss: 0.0547 - val_mean_absolute_error: 0.1788
# Epoch 29/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1052 - mean_absolute_error: 0.2282 - val_loss: 0.0971 - val_mean_absolute_error: 0.2580
# Epoch 30/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1041 - mean_absolute_error: 0.2304 - val_loss: 0.0902 - val_mean_absolute_error: 0.2471
# Epoch 31/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1037 - mean_absolute_error: 0.2277 - val_loss: 0.0857 - val_mean_absolute_error: 0.2460
# Epoch 32/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1036 - mean_absolute_error: 0.2284 - val_loss: 0.0701 - val_mean_absolute_error: 0.2176
# Epoch 33/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1001 - mean_absolute_error: 0.2302 - val_loss: 0.0533 - val_mean_absolute_error: 0.1787
# Epoch 34/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1026 - mean_absolute_error: 0.2287 - val_loss: 0.0839 - val_mean_absolute_error: 0.2400
# Epoch 35/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1008 - mean_absolute_error: 0.2264 - val_loss: 0.0672 - val_mean_absolute_error: 0.2096
# Epoch 36/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1008 - mean_absolute_error: 0.2232 - val_loss: 0.0895 - val_mean_absolute_error: 0.2475
# Epoch 37/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1006 - mean_absolute_error: 0.2262 - val_loss: 0.0897 - val_mean_absolute_error: 0.2474
# Epoch 38/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0981 - mean_absolute_error: 0.2207 - val_loss: 0.1058 - val_mean_absolute_error: 0.2707
# Epoch 39/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0986 - mean_absolute_error: 0.2250 - val_loss: 0.0483 - val_mean_absolute_error: 0.1637
# Epoch 40/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0970 - mean_absolute_error: 0.2214 - val_loss: 0.1241 - val_mean_absolute_error: 0.2926
# Epoch 41/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0978 - mean_absolute_error: 0.2255 - val_loss: 0.0765 - val_mean_absolute_error: 0.2170
# Epoch 42/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0982 - mean_absolute_error: 0.2218 - val_loss: 0.0780 - val_mean_absolute_error: 0.2310
# Epoch 43/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0976 - mean_absolute_error: 0.2206 - val_loss: 0.0737 - val_mean_absolute_error: 0.2197
# Epoch 44/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0957 - mean_absolute_error: 0.2188 - val_loss: 0.0958 - val_mean_absolute_error: 0.2536
# Epoch 45/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0969 - mean_absolute_error: 0.2187 - val_loss: 0.0618 - val_mean_absolute_error: 0.1965
# Epoch 46/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0964 - mean_absolute_error: 0.2207 - val_loss: 0.0934 - val_mean_absolute_error: 0.2497
# Epoch 47/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0973 - mean_absolute_error: 0.2218 - val_loss: 0.0744 - val_mean_absolute_error: 0.2200
# Epoch 48/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0960 - mean_absolute_error: 0.2169 - val_loss: 0.0703 - val_mean_absolute_error: 0.2088
# Epoch 49/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0967 - mean_absolute_error: 0.2179 - val_loss: 0.0651 - val_mean_absolute_error: 0.2018
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0947 - mean_absolute_error: 0.2186 - val_loss: 0.0589 - val_mean_absolute_error: 0.1884

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# Now we will parametrize the model to vary the prediction horizon $p$ and the output prediction order $d_y$.

# %%
def new_train(p, dy):                                 
    nn_0=dy+1                              
    nn_1=10                                  
    nn_2=1                                   
    y=S

    V=y[dy:len(y)-p,]
    for i in range(1, dy+1):
        V=np.c_[V,y[dy-i:len(y)-p-i,]]   

    T=np.mat(y[dy+p:len(y),]).T

    input_NN=V[:400,:]
    target_NN=T[:400,]
    input_Test=V[400:,:]
    target_Test=T[400:,]

    input_mean = np.mean(input_NN)
    target_mean = np.mean(target_NN)
    input_std = np.std(input_NN)
    target_std = np.std(target_NN)

    input_NN = (input_NN - input_mean) / input_std
    target_NN = (target_NN - input_mean) / target_std
    input_Test = (input_Test - input_mean) / input_std
    target_Test = (target_Test - target_mean) / target_std

    model = models.Sequential()

    model.add(layers.Dense(nn_0, activation=activations.linear))
    model.add(layers.Dense(nn_1, activation=activations.relu))
    model.add(layers.Dense(nn_2, activation=activations.linear))

    model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001), loss=losses.mean_squared_error, metrics=[metrics.mean_absolute_error])

    history = model.fit(input_NN, target_NN, epochs=50, batch_size=4, validation_data=(input_Test, target_Test), verbose=0)

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss p={} dy={}'.format(p, dy))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()

    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('Model MAE p={} dy={}'.format(p, dy))
    plt.ylabel('MAE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()

for p in range(1, 4):
    for dy in range(7, 11):
        new_train(p, dy)
